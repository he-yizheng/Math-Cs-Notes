// %% [markdown]
// ### Question 2
// - (a) Big Theta(n^2)
// - (b) Big Theta(n^2)
// - (c) Big Theta (n)
// - (d) Big Theta (n^2 * sqrt(n)) (*)
// - (e) Big Theta (n^2 * log(n)) (*)
// - (f) Big Theta (n^3) (*)
//
// ### Question 3

// %%
<T> void reverseBottomK(Stack<T> s, int k) {
    Stack<T> temp1 = new Stack<>();
    while (s.size() > k) {
        temp1.push(s.pop());
    }
    Stack<T> temp2 = new Stack<>();
    while (!s.isEmpty()) {
        temp2.push(s.pop());
    }
    while (!temp1.isEmpty()) {
        temp2.push(temp1.pop());
    }
    s = temp2;
    // Stack<T> temp3 = new Stack<>();
    // while (!temp2.isEmpty()) {
    //     temp3.push(temp2.pop());
    // }
    // while (!temp3.isEmpty()) {
    //     s.push(temp3.pop());
    // }

    // why I can't do s = temp2 ?
    // see thing in the enqueue like
}

public static void main(String[] args) {
    Stack<Integer> stack = new Stack<>();
    stack.push(1);
    stack.push(2);
    stack.push(3);
    stack.push(4);
    stack.push(5);

    int k = 3;

    System.out.println("Original Stack: " + stack);
    reverseBottomK(stack, k);
    System.out.println("Stack after reversing bottom " + k + " elements: " + stack);
}

reverseBottomK(s,k) {
    create an empty Stack s2;
    create a empty queue q;
    n = s.size();
    for i from 1 to n - k:
        s2.push(s.pop());
    for i from 1 to k:
        q.enqueue(s.pop());
    for i from 1 to n:
        if i < k: // <=??
            s.push(q.dequeue());
        else:
            s.push(s2.pop());
}

enqueue (element) {
    if (size == queue.length) {
        // increase length of array
        create a bigger array tep[] // e.g. 2*length
        for i = 0 to queue.length - 1:
            tmp[i] = queue[(head + i) mod queue.length]
        head = 0
        queue = tmp
    }
    queue[(head + size) mod queue.length] = element
    size ++
}

dequeue() {
    if size <= 0
        raise error
    
    element = queue[head]
    size = size - 1
    head = (head + 1) mod length
    return element
}
